# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vehicle-dataset-from-cardekho/car data.csv
# /kaggle/input/vehicle-dataset-from-cardekho/CAR DETAILS FROM CAR DEKHO.csv
# /kaggle/input/vehicle-dataset-from-cardekho/Car details v3.csv

# %%
df=pd.read_csv('/kaggle/input/vehicle-dataset-from-cardekho/Car details v3.csv')

# %%
df.sample(10)
# Out:
#                                 name  year  selling_price  km_driven    fuel  \
# 5379         Maruti Baleno Sigma 1.3  2017         625000      70000  Diesel
# 4869             Maruti Alto 800 LXI  2016         315000      25000  Petrol
# 770            Mahindra Xylo D4 BSIV  2012         350000     120000  Diesel
# 4280    Maruti Ciaz RS ZDi Plus SHVS  2016         750000      80000  Diesel
# 415               Maruti Wagon R LXI  2013         225000      58343  Petrol
# 768           Maruti Swift Dzire VDi  2012         420000     120000  Diesel
# 5673            Toyota Etios Liva GD  2012         275000     120000  Diesel
# 3553     Skoda Laura Ambiente 1.9 PD  2008         229999     110000  Diesel
# 2512            Ford Figo Diesel EXI  2010         200000     120000  Diesel
# 4187  Renault Duster 85PS Diesel RxS  2017         819999      50000  Diesel
#
#            seller_type transmission                 owner     mileage  \
# 5379        Individual       Manual           First Owner  27.39 kmpl
# 4869        Individual       Manual           First Owner  22.74 kmpl
# 770         Individual       Manual  Fourth & Above Owner   14.0 kmpl
# 4280        Individual       Manual           First Owner  28.09 kmpl
# 415   Trustmark Dealer       Manual           First Owner  21.79 kmpl
# 768         Individual       Manual          Second Owner   19.3 kmpl
# 5673        Individual       Manual          Second Owner         NaN
# 3553        Individual       Manual          Second Owner   17.5 kmpl
# 2512        Individual       Manual           First Owner   20.0 kmpl
# 4187        Individual       Manual           First Owner  19.87 kmpl
#
#        engine  max_power                   torque  seats
# 5379  1248 CC     74 bhp           190Nm@ 2000rpm    5.0
# 4869   796 CC   47.3 bhp            69Nm@ 3500rpm    5.0
# 770   2498 CC    112 bhp  260 Nm at 1800-2200 rpm    8.0
# 4280  1248 CC   88.5 bhp           200Nm@ 1750rpm    5.0
# 415    998 CC  67.05 bhp            90Nm@ 3500rpm    5.0
# 768   1248 CC   73.9 bhp           190Nm@ 2000rpm    5.0
# 5673      NaN        NaN                      NaN    NaN
# 3553  1896 CC    106 bhp    25.5@ 1,900(kgm@ rpm)    5.0
# 2512  1399 CC     68 bhp           160Nm@ 2000rpm    5.0
# 4187  1461 CC   83.8 bhp           200Nm@ 1750rpm    5.0

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.duplicated().sum()
# Out:
# 1202

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
#Observations
#1.Missing values in some cols
#2.Seats is float should be int
#3.More than 1k duplicates
#4.Outliers in year,selling price
#5.Torque,Engine,Milleage & max_power have unnecessary units

# %%
#drop any row with missing values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7906, 13)

# %%
#no.of dropped rows is
8128-7906
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
#remove duplicate rows
df=df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (6717, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#change datatype of seats col
df['seats']=df['seats'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6717 entries, 0 to 8125
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   object
#  9   engine         6717 non-null   object
#  10  max_power      6717 non-null   object
#  11  torque         6717 non-null   object
#  12  seats          6717 non-null   int32
# dtypes: int32(1), int64(3), object(9)
# memory usage: 708.4+ KB

# %%
#Handling mileage col
df['mileage']=df['mileage'].str.split(expand=True)[0]

# %%
df['mileage']=df['mileage'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6717 entries, 0 to 8125
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   float64
#  9   engine         6717 non-null   object
#  10  max_power      6717 non-null   object
#  11  torque         6717 non-null   object
#  12  seats          6717 non-null   int32
# dtypes: float64(1), int32(1), int64(3), object(8)
# memory usage: 708.4+ KB

# %%
#Handling engine col
df['engine']=df['engine'].str.split(expand=True)[0]
df['engine']=df['engine'].astype('int32')

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine   max_power  \
# 0  Individual       Manual   First Owner    23.40    1248      74 bhp
# 1  Individual       Manual  Second Owner    21.14    1498  103.52 bhp
# 2  Individual       Manual   Third Owner    17.70    1497      78 bhp
# 3  Individual       Manual   First Owner    23.00    1396      90 bhp
# 4  Individual       Manual   First Owner    16.10    1298    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm      5
# 1       250Nm@ 1500-2500rpm      5
# 2     12.7@ 2,700(kgm@ rpm)      5
# 3  22.4 kgm at 1750-2750rpm      5
# 4     11.5@ 4,500(kgm@ rpm)      5

# %%
#Handling max_power col
df['max_power']=df['max_power'].str.split(expand=True)[0]
df['max_power']=df['max_power'].astype('float64')

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  \
# 0  Individual       Manual   First Owner    23.40    1248      74.00
# 1  Individual       Manual  Second Owner    21.14    1498     103.52
# 2  Individual       Manual   Third Owner    17.70    1497      78.00
# 3  Individual       Manual   First Owner    23.00    1396      90.00
# 4  Individual       Manual   First Owner    16.10    1298      88.20
#
#                      torque  seats
# 0            190Nm@ 2000rpm      5
# 1       250Nm@ 1500-2500rpm      5
# 2     12.7@ 2,700(kgm@ rpm)      5
# 3  22.4 kgm at 1750-2750rpm      5
# 4     11.5@ 4,500(kgm@ rpm)      5

# %%
#dropping torque col
df.drop(columns=['torque'],inplace=True)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  seats
# 0  Individual       Manual   First Owner    23.40    1248      74.00      5
# 1  Individual       Manual  Second Owner    21.14    1498     103.52      5
# 2  Individual       Manual   Third Owner    17.70    1497      78.00      5
# 3  Individual       Manual   First Owner    23.00    1396      90.00      5
# 4  Individual       Manual   First Owner    16.10    1298      88.20      5

# %%
df.shape
# Out:
# (6717, 12)

# %%
df['name'].unique().shape
# Out:
# (1982,)

# %%
#extracting brand from name
df['brand']=df['name'].str.split(expand=True)[0]

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  seats  \
# 0  Individual       Manual   First Owner    23.40    1248      74.00      5
# 1  Individual       Manual  Second Owner    21.14    1498     103.52      5
# 2  Individual       Manual   Third Owner    17.70    1497      78.00      5
# 3  Individual       Manual   First Owner    23.00    1396      90.00      5
# 4  Individual       Manual   First Owner    16.10    1298      88.20      5
#
#      brand
# 0   Maruti
# 1    Skoda
# 2    Honda
# 3  Hyundai
# 4   Maruti

# %%
#drop name col
df.drop(columns=['name'],inplace=True)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner  mileage  engine  max_power  seats    brand
# 0   First Owner    23.40    1248      74.00      5   Maruti
# 1  Second Owner    21.14    1498     103.52      5    Skoda
# 2   Third Owner    17.70    1497      78.00      5    Honda
# 3   First Owner    23.00    1396      90.00      5  Hyundai
# 4   First Owner    16.10    1298      88.20      5   Maruti

# %%
freq_brands=df['brand'].value_counts()[df['brand'].value_counts()>100].index.tolist()

# %%
freq_brands
# Out:
# ['Maruti',
#  'Hyundai',
#  'Mahindra',
#  'Tata',
#  'Honda',
#  'Ford',
#  'Toyota',
#  'Chevrolet',
#  'Renault',
#  'Volkswagen']

# %%
df=df[df['brand'].isin(freq_brands)]

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
# 5  2017         440000      45000  Petrol  Individual       Manual
#
#          owner  mileage  engine  max_power  seats    brand
# 0  First Owner    23.40    1248      74.00      5   Maruti
# 2  Third Owner    17.70    1497      78.00      5    Honda
# 3  First Owner    23.00    1396      90.00      5  Hyundai
# 4  First Owner    16.10    1298      88.20      5   Maruti
# 5  First Owner    20.14    1197      81.86      5  Hyundai

# %%
freq_fuel=['Diesel','Petrol']
df=df[df['fuel'].isin(freq_fuel)]

# %%
df.shape
# Out:
# (6192, 12)

# %%
df['seller_type'].value_counts()
# Out:
# Individual          5607
# Dealer               560
# Trustmark Dealer      25
# Name: seller_type, dtype: int64

# %%
df=df[df['seller_type'].isin(['Individual','Dealer'])]

# %%
df.shape
# Out:
# (6167, 12)

# %%
df['transmission'].value_counts()
# Out:
# Manual       5783
# Automatic     384
# Name: transmission, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# First Owner             3806
# Second Owner            1750
# Third Owner              459
# Fourth & Above Owner     150
# Test Drive Car             2
# Name: owner, dtype: int64

# %%
df=df[df['owner'].isin(['First Owner','Second Owner','Third Owner'])]

# %%
df.shape
# Out:
# (6015, 12)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
# 5  2017         440000      45000  Petrol  Individual       Manual
#
#          owner  mileage  engine  max_power  seats    brand
# 0  First Owner    23.40    1248      74.00      5   Maruti
# 2  Third Owner    17.70    1497      78.00      5    Honda
# 3  First Owner    23.00    1396      90.00      5  Hyundai
# 4  First Owner    16.10    1298      88.20      5   Maruti
# 5  First Owner    20.14    1197      81.86      5  Hyundai

# %%
import seaborn as sns
sns.boxplot(df['km_driven'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='km_driven'>

# %%
q1=df['km_driven'].quantile(0.25)
q3=df['km_driven'].quantile(0.75)
iqr=q3-q1

# %%
max_val_km_driven=q3+1.5*iqr

# %%
max_val_km_driven
# Out:
# 193000.0

# %%
df['km_driven']=np.where(df['km_driven']>max_val_km_driven,max_val_km_driven,df['km_driven'])

# %%
sns.boxplot(df['km_driven'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='km_driven'>

# %%
df=df[df['year']>=2000]

# %%
sns.boxplot(df['year'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='year'>

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000   145500.0  Diesel  Individual       Manual
# 2  2006         158000   140000.0  Petrol  Individual       Manual
# 3  2010         225000   127000.0  Diesel  Individual       Manual
# 4  2007         130000   120000.0  Petrol  Individual       Manual
# 5  2017         440000    45000.0  Petrol  Individual       Manual
#
#          owner  mileage  engine  max_power  seats    brand
# 0  First Owner    23.40    1248      74.00      5   Maruti
# 2  Third Owner    17.70    1497      78.00      5    Honda
# 3  First Owner    23.00    1396      90.00      5  Hyundai
# 4  First Owner    16.10    1298      88.20      5   Maruti
# 5  First Owner    20.14    1197      81.86      5  Hyundai

# %%
sns.boxplot(df['mileage'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='mileage'>

# %%
mean_mileage=df[df['mileage']!=0]['mileage'].median()
mean_mileage
# Out:
# 19.7

# %%
df['mileage']=np.where(df['mileage']==0,mean_mileage,df['mileage'])

# %%
sns.boxplot(df['mileage'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='mileage'>

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000   145500.0  Diesel  Individual       Manual
# 2  2006         158000   140000.0  Petrol  Individual       Manual
# 3  2010         225000   127000.0  Diesel  Individual       Manual
# 4  2007         130000   120000.0  Petrol  Individual       Manual
# 5  2017         440000    45000.0  Petrol  Individual       Manual
#
#          owner  mileage  engine  max_power  seats    brand
# 0  First Owner    23.40    1248      74.00      5   Maruti
# 2  Third Owner    17.70    1497      78.00      5    Honda
# 3  First Owner    23.00    1396      90.00      5  Hyundai
# 4  First Owner    16.10    1298      88.20      5   Maruti
# 5  First Owner    20.14    1197      81.86      5  Hyundai

# %%
df.shape
# Out:
# (5988, 12)

# %%
# Ordinal Encoding on owner col
X=df.drop(columns=['selling_price'])
y=df['selling_price']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
y_train
# Out:
# 4996    200000
# 2063    351000
# 5788    200000
# 593     300000
# 5191    300000
#          ...
# 1417    395000
# 3212    950000
# 4808    750000
# 7680    550000
# 3290    370000
# Name: selling_price, Length: 4790, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
tnf=ColumnTransformer(
    [
        ('ordinal',OrdinalEncoder(),['owner']),
        ('nominal',OneHotEncoder(drop='first',sparse=False),['fuel','seller_type','transmission','brand'])
    ], remainder='passthrough'
)

# %%
#X_train_tnf=tnf.fit_transform(X_train)
#X_test_tnf=tnf.transform(X_test)

# %%
#X_train_tnf[0]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
#lr.fit(X_train_tnf,y_train)

# %%
#y_pred=lr.predict(X_test_tnf)

# %%
from sklearn.metrics import r2_score
#r2_score(y_test,y_pred)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)

# %%
#X_train_poly=poly.fit_transform(X_train_tnf)
#X_test_poly=poly.transform(X_test_tnf)

# %%
#lr=LinearRegression()
#lr.fit(X_train_poly,y_train)
#y_pred=lr.predict(X_test_poly)
#r2_score(y_test,y_pred)

# %%
# pipeline
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(
    [
        ('col-transformer',tnf),
        ('poly',poly),
        ('lr',lr)
    ]
)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('col-transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['owner']),
#                                                  ('nominal',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['fuel', 'seller_type',
#                                                    'transmission',
#                                                    'brand'])])),
#                 ('poly', PolynomialFeatures()), ('lr', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8774692471147335

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8774692471147335

# %%
import pickle
pickle.dump(pipe,open('pipe.p','wb'))
